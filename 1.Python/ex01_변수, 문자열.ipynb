# %% [markdown]
# # 마크다운
# ## 마크다운
# ### 마크다운
#
#     - 마크다운
#     ` 마크다운

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 공통단축키(실행)
#
# - Ctrl + Enter : 현재 셀 실행
# - Alt + Enter : 현재 셀 실행 후, 아래 셀 추가
# - Shift + Enter : 현재 셀 실행 후, 아래 셀 이동

# %%
# 주석은 #으로

# %%
1+3
# Out:
# 4

# %%
print(1+3)
# Out:
# 4

# %% [markdown]
# ### 1. 변수
# - 변할 수 있는 수
# - 프로그래밍 : 데이터를 담을 수 있는 공간

# %%
#동적 자료형:값을 넣는 순간 형태(자료형)가 정해진다
a = 1
a
b = "스마트인재개발원"
b
# Out:
# '스마트인재개발원'

# %% [markdown]
# #### 1.1 변수명 규칙
# 1. 영문자, 숫자, 언더바(_) 를 사용가능
#     - ⚠ 주의사항 : 대문자와 소문자를 다르게 인식
# 2. 숫자로 시작 불가능
# 3. 키워드(예약어) 사용 불가능)
# 4. 변수명의 첫 글자는 항상 소문자로 지정(권장사항)
#     - camelCase, snake_case

# %%
# a와 b라는 변수에 각각 10과 15를 대입
a=10
b=15
#print() 함수는 한 셀에서 여러가지 출력값이 필요할 때 사용한다
print(a)
print(b)
print(a,b)
# Out:
# 10
# 15
# 10 15

# %%
#여러개의 변수 할당 가능
c, d = 10, 15
c, d
# Out:
# (10, 15)

# %%
#문자열 : "", '' 둘다 가능
#같은 값을 다른 변수에 할당하고 싶은 경우
str1 = "python"
str2 = 'python'
print(str1, str2)
str1, str2
# Out:
# python python
# ('python', 'python')

# %%
#python 문자열은 str4에 들어가고, str4에 들어가있는 값은 str3에 들어감
str3 = str4 = "python"
print(str3, str4)
# Out:
# python python

# %%
x,y=100,200
# sum = x + y
add = x+y
print(add)
#sum은 내장함수라 오류는 안나지만 올바른 사용법은 아님
#sum((1,2,3,4,5)) 실행 시 합을 구해주는 함수이나 변수명으로 사용하고 이후에 sum을 사용하면 그 기능을 상실함
#한번 잃어버린 기능은 파이썬 서버를 닫고 재시작하면 자동으로 되살아남
# Out:
# 300

# %%
sum((1,2,3,4,5))
# Out:
# 15

# %%
#자료형 확인하는 방법
type(x)

#해당 자료형이 맞는지 검사
isinstance(x, int)
# Out:
# True

# %% [markdown]
# ### 2. 문자열

# %%
s = '스마트인재개발원'
s
# Out:
# '스마트인재개발원'

# %%
#문자열안에 작은따옴표나 큰따옴표를 포함시키고 싶을 때
s = "she's gone"
s

# %%
#이스케이프코드 활용(\)
s = 'she\'s gone'
s
# Out:
# "she's gone"

# %% [markdown]
# #### 이스케이프코드
# - 프로그래밍 할 때 사용할 수 있도록 미리 정의해둔 문자 조합
# ![image.png](attachment:image.png)

# %%
s = "파이썬 \n - 동적언어 \n - 직관적, 명시적, 간결함"
print(s)
# Out:
# 파이썬
#  - 동적언어
#  - 직관적, 명시적, 간결함

# %%
#긴줄 문자열 기호: 여러줄인 문자열을 변수에 대입하고 싶을 때!
s1 = """파이썬 
 -동적 
 -직관적, 명시적, 간결함"""
#s1 출력하면 파이썬 \n - 동적언어 \n - 직관적, 명시적, 간결함 이렇게 나옴
print(s1)
# Out:
# 파이썬
#  -동적
#  -직관적, 명시적, 간결함

# %%
#natural language processing (NLP)

# %% [markdown]
# #### 문자열 인덱싱, 슬라이싱
# - 인덱스(Index): 데이터가 생성될 때 자동으로 부여되는 순서(번호)
# - 인덱싱(Indexing) : 무엇인가를 <b>가리킨다</b> 는 의미
# - 슬라이싱(Slicing) : 무엇인가를 <b>잘라낸다</b> 는 의미

# %%
str1 = "My name is BG"
print(str1[0])
print(str1[8]) #정수 인덱싱
# Out:
# M
# i

# %%
# 인덱싱이 양수뿐만 아닌 음수로도 가능하다.
print(str1[-2])
print(str1[-1]) 
print(str1[-13])
# Out:
# B
# G
# M

# %%
# 슬라이싱
#변수명[시작값(포함):끝값(미포함)]
print(str1[0:2])
print(str1[3:7])
# Out:
# My
# name

# %%
#슬라이싱 문법
#생략 -> 처음부터/끝까지

print(str1[0:]) #처음부터
print(str1[-13:])#끝까지
# Out:
# My name is BG
# My name is BG

# %% [markdown]
# #### 문자열 포매팅(formatting)
# - 문자열 안의 특정한 값을 바꿔야(수정)할 때 사용

# %%
s = '오늘은 1월 22일 입니다'

# %%
# 1. %기호 포매팅
month =1
day = 23
# 두가지 값을 포매팅 할 경우 튜플로(()) 감싸주어야함
s = '오늘은 %d월 %d일 입니다' %(month,day)
s
# Out:
# '오늘은 1월 23일 입니다'

# %% [markdown]
# #### 문자열 포맷 코드
# ![image.png](attachment:image.png)

# %%
# 2. format 함수 포매팅
month =1
day = 27
s = '오늘은 {}월 {}일 입니다'.format(month,day)
s
# Out:
# '오늘은 1월 27일 입니다'

# %%
# 3. f문자열 포매팅
month =1
day = 23
s = f'오늘은 {month}월 {day}일 입니다' 
s
# Out:
# '오늘은 1월 23일 입니다'

# %%
#변수 X에는 100을 대입, 변수 y에는 200을 대입 후
#변수 add 에 두 변수의 합을 대입하고, 포매팅을 이용하여 출력

# %%
x, y = 100, 200
add = x+y
print(f"{x}과 {y}의 합은 {add}입니다.")
print("{}과 {}의 합은 {}입니다.".format(x,y,add))
print("%d과 %d의 합은 %d입니다." %(x,y,add))
# Out:
# 100과 200의 합은 300입니다.
# 100과 200의 합은 300입니다.
# 100과 200의 합은 300입니다.

# %% [markdown]
# | 함수 | 사용법 | 설명 | 반환값 |
# |------|--------|------|-------|
# | replace | `str.replace(old, new[, count])` | 문자열에서 `old`를 `new`로 대체 | 새 문자열 |
# | upper | `str.upper()` | 문자열의 모든 문자를 대문자로 변환 | 새 문자열 |
# | lower | `str.lower()` | 문자열의 모든 문자를 소문자로 변환 | 새 문자열 |
# | strip | `str.strip([chars])` | 문자열 양쪽 끝의 공백이나 `chars`에 지정된 문자 제거 | 새 문자열 |
# | lstrip | `str.lstrip([chars])` | 문자열 왼쪽 끝의 공백이나 `chars`에 지정된 문자 제거 | 새 문자열 |
# | rstrip | `str.rstrip([chars])` | 문자열 오른쪽 끝의 공백이나 `chars`에 지정된 문자 제거 | 새 문자열 |
# | find | `str.find(sub[, start[, end]])` | 부분 문자열 `sub`이 처음 나타나는 위치 탐색 | 위치 인덱스 또는 -1 |
# | rfind | `str.rfind(sub[, start[, end]])` | 부분 문자열 `sub`이 마지막으로 나타나는 위치 탐색 | 위치 인덱스 또는 -1 |
# | split | `str.split([sep[, maxsplit]])` | `sep`을 기준으로 문자열을 나눔 | 문자열 리스트 |
# | rsplit | `str.rsplit([sep[, maxsplit]])` | `sep`을 기준으로 문자열을 오른쪽에서부터 나눔 | 문자열 리스트 |
# | join | `str.join(iterable)` | `iterable`의 각 요소를 문자열로 연결 | 새 문자열 |
# | count | `str.count(sub[, start[, end]])` | 문자열에서 부분 문자열 `sub`의 출현 횟수 계산 | 정수 |
# | index | `str.index(sub[, start[, end]])` | 부분 문자열 `sub`이 처음 나타나는 위치 탐색(찾지 못하면 예외 발생) | 위치 인덱스 |
# | rindex | `str.rindex(sub[, start[, end]])` | 부분 문자열 `sub`이 마지막으로 나타나는 위치 탐색(찾지 못하면 예외 발생) | 위치 인덱스 |
# | startswith | `str.startswith(prefix[, start[, end]])` | 문자열이 지정된 접두어로 시작하는지 여부 | 불리언 |
# | endswith | `str.endswith(suffix[, start[, end]])` | 문자열이 지정된 접미어로 끝나는지 여부 | 불리언 |
# | isdigit | `str.isdigit()` | 문자열이 숫자로만 구성되어 있는지 여부 | 불리언 |
# | isalpha | `str.isalpha()` | 문자열이 알파벳 문자로만 구성되어 있는지 여부 | 불리언 |
# | isalnum | `str.isalnum()` | 문자열이 알파벳 문자와 숫자로만 구성되어 있는지 여부 | 불리언 |
# | isspace | `str.isspace()` | 문자열이 공백 문자로만 구성되어 있는지 여부 | 불리언 |
# | istitle | `str.istitle()` | 문자열이 타이틀 케이스(각 단어의 첫 글자가 대문자)인지 여부 | 불리언 |
# | capitalize | `str.capitalize()` | 문자열의 첫 글자를 대문자로, 나머지는 소문자로 변환 | 새 문자열 |
# | title | `str.title()` | 각 단어의 첫 글자를 대문자로, 나머지는 소문자로 변환 | 새 문자열 |
# | zfill | `str.zfill(width)` | 문자열의 왼쪽을 '0'으로 채워 지정된 너비에 맞춤 | 새 문자열 |
# | ljust | `str.ljust(width[, fillchar])` | 문자열을 지정된 너비로 왼쪽 정렬 | 새 문자열 |
# | rjust | `str.rjust(width[, fillchar])` | 문자열을 지정된 너비로 오른쪽 정렬 | 새 문자열 |
# | center | `str.center(width[, fillchar])` | 문자열을 지정된 너비로 중앙 정렬 | 새 문자열 |
# | encode | `str.encode(encoding='utf-8', errors='strict')` | 문자열을 지정된 인코딩으로 인코딩 | 바이트 객체 |
# | format | `str.format(*args, **kwargs)` | 문자열의 형식을 지정된 값으로 채움 | 새 문자열 |
